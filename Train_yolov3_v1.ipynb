# %%
# !nvidia-smi
# Out:
# Wed May 18 14:31:16 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!unzip '/content/drive/MyDrive/yolov3_v1/images.zip' -d '/content/drive/MyDrive/yolov3_v1/images'

# %%
# !ls '/content/drive/MyDrive/yolov3_v1'
# Out:
# backup	  chart.png		   custom_weight  darknet1  images.zip
# bad.list  chart_yolov3_custom.png  darknet	  images

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolov3_v1/darknet'

# %%
# %cd /content/drive/MyDrive/yolov3_v1/darknet
# Out:
# /content/drive/MyDrive/yolov3_v1/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/MyDrive/yolov3_v1
# Out:
# /content/drive/MyDrive/yolov3_v1

# %%
# !python3 /content/drive/MyDrive/yolov3_v1/images/creating-files-data-and-name.py

# %%
# !python3 /content/drive/MyDrive/yolov3_v1/images/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train images/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.937621), count: 10, class_loss = 0.000002, iou_loss = 0.024622, total_loss = 0.024624
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/MyDrive/yolov3_v1/images/img88.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/MyDrive/yolov3_v1/images/img91.txt
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 1791109, rewritten_bbox = 0.073139 %
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/MyDrive/yolov3_v1/images/img86.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/MyDrive/yolov3_v1/images/img91.txt
# ...

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>
